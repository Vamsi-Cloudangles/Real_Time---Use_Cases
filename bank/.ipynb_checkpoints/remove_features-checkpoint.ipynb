# %%
import pandas as pd

# %%
dataset = pd.read_csv('bank.csv')

# %%
dataset.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
print (dataset.columns)
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
length = int(input("How many columns you need to remove : "))
col = list(map(str,input("\n Enter the Unwanted Columns : ").strip().split()))[:length]
print('\n')    
dataset.drop(col, axis = 1)
# Out:
# How many columns you need to delete3
#
#  Enter the Unwanted Columns : job day pdays
#        age   marital  education default  balance housing loan    contact  \
# 0       58   married   tertiary      no     2143     yes   no    unknown
# 1       44    single  secondary      no       29     yes   no    unknown
# 2       33   married  secondary      no        2     yes  yes    unknown
# 3       47   married    unknown      no     1506     yes   no    unknown
# 4       33    single    unknown      no        1      no   no    unknown
# ...    ...       ...        ...     ...      ...     ...  ...        ...
# 45206   51   married   tertiary      no      825      no   no   cellular
# 45207   71  divorced    primary      no     1729      no   no   cellular
# 45208   72   married  secondary      no     5715      no   no   cellular
# 45209   57   married  secondary      no      668      no   no  telephone
# 45210   37   married  secondary      no     2971      no   no   cellular
#
# ...
